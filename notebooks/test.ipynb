# %%
from qiskit import QuantumCircuit

# %%
qc = QuantumCircuit.from_qasm_file(
    "../benchmarks/qaoa_20.qasm"
)

# %%
print("Qubits:", qc.num_qubits)
print("Depth:", qc.depth())
print("2Q gates:", qc.num_nonlocal_gates())
# Out:
# Qubits: 20
# Depth: 48
# 2Q gates: 184

# %%
import maestro
print(dir(maestro))
# Out:
# ['CompositeQCSim', 'ExtendedStabilizer', 'Gpu', 'Maestro', 'MatrixProductState', 'NoiseModel', 'PathIntegral', 'PauliPropagator', 'QCSim', 'QasmToCirc', 'QuestSim', 'SimulationType', 'SimulatorConfig', 'SimulatorType', 'Stabilizer', 'Statevector', 'TensorNetwork', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'circuits', 'coherent_estimate', 'coherent_execute', 'full_noise_estimate', 'full_noise_execute', 'get_probabilities', 'get_statevector', 'init_gpu', 'init_quest', 'inner_product', 'is_gpu_available', 'is_quest_available', 'mirror_fidelity', 'noisy_estimate', 'noisy_estimate_montecarlo', 'noisy_execute', 'simple_estimate', 'simple_execute', 'state_probability']

# %%
from qiskit import QuantumCircuit

qc = QuantumCircuit.from_qasm_file("../benchmarks/qft_10.qasm")

print(qc.count_ops())
# Out:
# OrderedDict({'measure': 10, 'qft': 1, 'barrier': 1})

# %%
from qiskit import QuantumCircuit

qc = QuantumCircuit.from_qasm_file("../benchmarks/qaoa_10.qasm")

print(qc.count_ops())
# Out:
# OrderedDict({'rzz': 52, 'rx': 20, 'h': 10})
